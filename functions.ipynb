# %%
def is_palindrome(n):
    return str(n)==str(n[::-1])

# %%
# Full Python Program
# import sys


n=int(input("enter a num"))
def isPalindrome(n):
  return str(n) == str(n)[::-1]

if isPalindrome(n):
    print("Palindrome")
else:
    print("Not Palindrome")


# Sample Run
# print(solve_function_call)
# Out:
# Not Palindrome

# %%
def isarmstrong():
    return sum(n)
# Out:
# hi

# %%
# Out:
# '55'

# %%
print("hi")
# Out:
# hi
