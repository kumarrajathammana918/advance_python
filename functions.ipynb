# %%
def is_palindrome(n):
    return str(n)==str(n[::-1])

# %%
# Full Python Program
# import sys


n=int(input("enter a num"))
def isPalindrome(n):
  return str(n) == str(n)[::-1]

if isPalindrome(n):
    print("Palindrome")
else:
    print("Not Palindrome")


# Sample Run
# print(solve_function_call)
# Out:
# Not Palindrome

# %%
import math

def is_factorial(n):
    return math.factorial(n)
# n = int(input("Enter number: "))

print(is_factorial(5))
# Out:
# 120

# %%
def is_leap(a):
    return a%4==0

a=int(input("entera year"))

if a==0:
    print("its a leap year")

else:
    print("Its not a leap")

print(is_leap(a))
# Out:
# Its not a leap
# 0

# %%
# Out:
# '55'

# %%
# Out:
# hi
